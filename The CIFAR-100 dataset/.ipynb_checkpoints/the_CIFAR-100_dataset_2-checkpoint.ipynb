# %% [markdown]
# #### Importing the libraries

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Loading the dataset

# %%
(X_train, y_train), (X_test,y_test) = tf.keras.datasets.cifar100.load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %% [markdown]
# #### Data Visualization

# %%
for i in range(5):
    plt.figure(figsize=(10,2))
    plt.imshow(X_train[i])
    #plt.xlabel(class_names[train_labels[i]])
    plt.show()

# %%
y_train
# Out:
# array([[19],
#        [29],
#        [ 0],
#        ...,
#        [ 3],
#        [ 7],
#        [73]])

# %% [markdown]
# #### Data Preprocessing

# %% [markdown]
# ##### Scale images

# %%
X_train_scaled = X_train / 255
X_test_scaled = X_test / 255

# %%
y_train
# Out:
# array([[19],
#        [29],
#        [ 0],
#        ...,
#        [ 3],
#        [ 7],
#        [73]])

# %% [markdown]
# #### Initializing the ANN

# %%
model = keras.Sequential([
            keras.layers.Flatten(input_shape=(32,32,3)),
            keras.layers.Dense(3000, activation='relu'),
            keras.layers.Dense(1000, activation='relu'),
            keras.layers.Dense(100, activation='sigmoid')    
        ])

# %% [markdown]
# #### Compiling the ANN

# %%
model.compile(optimizer='adam',
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy'])

# %% [markdown]
# #### Training the ANN on the Training set

# %%
history =  model.fit(X_train_scaled, y_train, batch_size = 32, epochs=10)
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 162s 103ms/step - loss: 4.3650 - accuracy: 0.0515
# Epoch 2/10
# 1563/1563 [==============================] - 159s 102ms/step - loss: 3.6565 - accuracy: 0.1383 - loss: 3.6566 - accuracy:
# Epoch 3/10
# 1563/1563 [==============================] - 142s 91ms/step - loss: 3.4823 - accuracy: 0.1691
# Epoch 4/10
# 1563/1563 [==============================] - 143s 92ms/step - loss: 3.3554 - accuracy: 0.1907
# Epoch 5/10
# 1563/1563 [==============================] - 148s 95ms/step - loss: 3.2505 - accuracy: 0.2138s -
# Epoch 6/10
# 1563/1563 [==============================] - 149s 95ms/step - loss: 3.1830 - accuracy: 0.2232
# Epoch 7/10
# 1563/1563 [==============================] - 156s 100ms/step - loss: 3.1127 - accuracy: 0.2338 - l
# Epoch 8/10
# 1563/1563 [==============================] - 158s 101ms/step - loss: 3.0723 - accuracy: 0.2414 - los
# Epoch 9/10
# 1563/1563 [==============================] - 155s 99ms/step - loss: 3.0158 - accuracy: 0.2509
# Epoch 10/10
# 1563/1563 [==============================] - 155s 99ms/step - loss: 2.9677 - accuracy: 0.2617

# %%
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.show()

# %% [markdown]
# #### Evaluate the model

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 313/313 [==============================] - 6s 19ms/step - loss: 3.4102 - accuracy: 0.2115
# [3.4101691246032715, 0.21150000393390656]

# %% [markdown]
# #### classification report

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred = model.predict(X_test_scaled)
y_pred_classes = [np.argmax(element) for element in y_pred]
print("Classification Report")
print(classification_report(y_test,y_pred_classes))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.40      0.36      0.38       100
#            1       0.25      0.30      0.27       100
#            2       0.11      0.17      0.13       100
#            3       0.11      0.08      0.09       100
#            4       0.08      0.07      0.08       100
#            5       0.16      0.11      0.13       100
#            6       0.33      0.14      0.20       100
#            7       0.35      0.17      0.23       100
#            8       0.10      0.31      0.16       100
#            9       0.45      0.27      0.34       100
#           10       0.08      0.02      0.03       100
#           11       0.13      0.08      0.10       100
#           12       0.22      0.23      0.22       100
#           13       0.24      0.13      0.17       100
#           14       0.15      0.15      0.15       100
#           15       0.18      0.10      0.13       100
#           16       0.25      0.15      0.19       100
#           17       0.24      0.44      0.31       100
#           18       0.22      0.21      0.22       100
#           19       0.15      0.24      0.18       100
#           20       0.43      0.38      0.40       100
#           21       0.22      0.45      0.30       100
#           22       0.18      0.11      0.14       100
#           23       0.36      0.20      0.26       100
#           24       0.37      0.41      0.39       100
#           25       0.09      0.08      0.08       100
#           26       0.12      0.18      0.15       100
#           27       0.06      0.04      0.05       100
#           28       0.43      0.25      0.32       100
#           29       0.18      0.04      0.07       100
#           30       0.28      0.24      0.26       100
#           31       0.14      0.22      0.17       100
#           32       0.16      0.14      0.15       100
#           33       0.17      0.29      0.21       100
#           34       0.19      0.21      0.20       100
#           35       0.13      0.18      0.15       100
#           36       0.18      0.22      0.20       100
#           37       0.14      0.24      0.18       100
#           38       0.11      0.24      0.15       100
#           39       0.18      0.10      0.13       100
#           40       0.22      0.13      0.16       100
#           41       0.32      0.48      0.38       100
#           42       0.09      0.25      0.13       100
#           43       0.13      0.14      0.14       100
#           44       0.14      0.05      0.07       100
#           45       0.17      0.12      0.14       100
#           46       0.17      0.14      0.15       100
#           47       0.37      0.31      0.34       100
#           48       0.23      0.41      0.29       100
#           49       0.17      0.21      0.19       100
#           50       0.08      0.03      0.04       100
#           51       0.14      0.11      0.12       100
#           52       0.44      0.63      0.52       100
#           53       0.60      0.32      0.42       100
#           54       0.17      0.53      0.26       100
#           55       0.07      0.05      0.06       100
#           56       0.32      0.29      0.31       100
#           57       0.28      0.13      0.18       100
#           58       0.22      0.23      0.22       100
#           59       0.18      0.10      0.13       100
#           60       0.37      0.63      0.47       100
#           61       0.33      0.35      0.34       100
#           62       0.35      0.20      0.25       100
#           63       0.22      0.24      0.23       100
#           64       0.04      0.02      0.03       100
#           65       0.08      0.05      0.06       100
#           66       0.05      0.04      0.04       100
#           67       0.41      0.11      0.17       100
#           68       0.58      0.32      0.41       100
#           69       0.41      0.32      0.36       100
#           70       0.32      0.51      0.39       100
#           71       0.28      0.45      0.35       100
#           72       0.14      0.06      0.08       100
#           73       0.32      0.17      0.22       100
#           74       0.16      0.08      0.11       100
#           75       0.29      0.22      0.25       100
#           76       0.23      0.52      0.32       100
#           77       0.14      0.12      0.13       100
#           78       0.10      0.06      0.07       100
#           79       0.17      0.09      0.12       100
#           80       0.06      0.03      0.04       100
#           81       0.09      0.06      0.07       100
#           82       0.54      0.63      0.58       100
#           83       0.16      0.12      0.14       100
#           84       0.08      0.06      0.07       100
#           85       0.37      0.23      0.28       100
#           86       0.28      0.27      0.27       100
#           87       0.20      0.24      0.22       100
#           88       0.07      0.09      0.08       100
#           89       0.39      0.15      0.22       100
#           90       0.16      0.08      0.11       100
#           91       0.26      0.32      0.28       100
#           92       0.14      0.12      0.13       100
#           93       0.26      0.16      0.20       100
#           94       0.23      0.47      0.31       100
#           95       0.19      0.41      0.26       100
#           96       0.19      0.24      0.21       100
#           97       0.14      0.17      0.15       100
#           98       0.09      0.04      0.05       100
#           99       0.18      0.09      0.12       100
#
#     accuracy                           0.21     10000
#    macro avg       0.22      0.21      0.20     10000
# weighted avg       0.22      0.21      0.20     10000

# %% [markdown]
# #### Heatmap

# %%
import seaborn as sn
cm = tf.math.confusion_matrix(labels = y_test, predictions = y_pred_classes)
plt.figure(figsize = (50,50))
sn.heatmap(data=cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(429.0, 0.5, 'Truth')
